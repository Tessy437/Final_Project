# %%
# pip install gTTS

# %%
from gtts import gTTS
from playsound import playsound
import shutil
import os

def create_voiceRecording():
    path = ("C:\\Users\\Tessy Benson\\Gesturemodel\\Consolidate\\Voice_Recordings")
    if not os.path.exists(path):
        os.mkdir(path)
        audio_0 = gTTS("0")
        audio_0.save("0.mp3")
        audio_1 = gTTS("1")
        audio_1.save("1.mp3")
        audio_2 = gTTS("2")
        audio_2.save("2.mp3")
        audio_3 = gTTS("3")
        audio_3.save("3.mp3")
        audio_4 = gTTS("4")
        audio_4.save("4.mp3")
        audio_5 = gTTS("5")
        audio_5.save("5.mp3")
        audio_6 = gTTS("6")
        audio_6.save("6.mp3")
        audio_7 = gTTS("7")
        audio_7.save("7.mp3")
        audio_8 = gTTS("8")
        audio_8.save("8.mp3")
        audio_9 = gTTS("9")
        audio_9.save("9.mp3")
        audio_angry = gTTS("angry")
        audio_angry.save("angry.mp3")
        audio_disgust = gTTS("disgust")
        audio_disgust.save("disgust.mp3")
        audio_fear = gTTS("fear")
        audio_fear.save("fear.mp3")
        audio_happy = gTTS("happy")
        audio_happy.save("happy.mp3")
        audio_neutral= gTTS("neutral")
        audio_neutral.save("neutral.mp3")
        audio_sad = gTTS("sad")
        audio_sad.save("sad.mp3")
        audio_surprise = gTTS("surprise")
        audio_surprise.save("surprise.mp3")
        audio_A = gTTS("A")
        audio_A.save("A.mp3")
        audio_B = gTTS("B")
        audio_B.save("B.mp3")
        audio_C = gTTS("C")
        audio_C.save("C.mp3")
        audio_D = gTTS("D")
        audio_D.save("D.mp3")
        audio_E= gTTS("E")
        audio_E.save("E.mp3")
        audio_F = gTTS("F")
        audio_F.save("F.mp3")
        audio_G = gTTS("G")
        audio_G.save("G.mp3")
        audio_H = gTTS("H")
        audio_H.save("H.mp3")
        audio_I = gTTS("I")
        audio_I.save("I.mp3")
        audio_J = gTTS("J")
        audio_J.save("J.mp3")
        audio_K = gTTS("K")
        audio_K.save("K.mp3")
        audio_L= gTTS("L")
        audio_L.save("L.mp3")
        audio_M = gTTS("M")
        audio_M.save("M.mp3")
        audio_N = gTTS("N")
        audio_N.save("N.mp3")
        audio_O = gTTS("O")
        audio_O.save("O.mp3")
        audio_P = gTTS("P")
        audio_P.save("P.mp3")
        audio_Q = gTTS("Q")
        audio_Q.save("Q.mp3")
        audio_R = gTTS("R")
        audio_R.save("R.mp3")
        audio_S= gTTS("S")
        audio_S.save("S.mp3")
        audio_T = gTTS("T")
        audio_T.save("T.mp3")
        audio_U = gTTS("U")
        audio_U.save("U.mp3")
        audio_V= gTTS("V")
        audio_V.save("V.mp3")
        audio_W = gTTS("W")
        audio_W.save("W.mp3")
        audio_X = gTTS("X")
        audio_X.save("X.mp3")
        audio_Y = gTTS("Y")
        audio_Y.save("Y.mp3")
        audio_Z = gTTS("Z")
        audio_Z.save("Z.mp3")
        voices = ['0.mp3','1.mp3','2.mp3','3.mp3','4.mp3','5.mp3','6.mp3','7.mp3','8.mp3','9.mp3','angry.mp3','disgust.mp3','fear.mp3','happy.mp3','neutral.mp3',
                          'sad.mp3','surprise.mp3','A.mp3','B.mp3','C.mp3','D.mp3','E.mp3','F.mp3','G.mp3','H.mp3','I.mp3',
                  'J.mp3','K.mp3','L.mp3','M.mp3','N.mp3','O.mp3','P.mp3','Q.mp3','R.mp3','S.mp3','T.mp3','U.mp3','V.mp3','W.mp3','X.mp3','Y.mp3','Z.mp3'] 
        for voice in voices:
            shutil.move(voice, path)

# %%
# create_voiceRecording()
